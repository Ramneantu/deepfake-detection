# %%
import json
import numpy as np
import matplotlib.pyplot as plt
import dlib
import utils as ut

# %%
img_path = "/Users/emrekavak/Desktop/c23/images/"
landmark_db_p = "/Users/emrekavak/Desktop/landmarks/landmark_db.txt"

# %%
with open(landmark_db_p, 'r') as myfile:
    landmark_db_f=myfile.read()

# %%
landmark_db = json.loads(landmark_db_f)

# %%
keys = list(landmark_db.keys())
values = list(landmark_db.values())

# %%
src_im = dlib.load_rgb_image(img_path+keys[110])

# %%
plt.imshow(src_im)

# %%
nearest_name = ut.get_nearest_face(keys[110], landmark_db)

# %%
nearest_im = dlib.load_rgb_image(img_path+nearest_name)

# %%
plt.imshow(nearest_im)
